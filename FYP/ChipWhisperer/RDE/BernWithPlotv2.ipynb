# %%
import numpy as np
import tensorflow as tf
import random as python_random
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import *
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l1, l2
import matplotlib.pyplot as plt
from tqdm import tqdm
import math
import random
import importlib

# Seed reset function
def reset_random_seeds(seed_value=42):
    python_random.seed(seed_value)
    np.random.seed(seed_value)
    tf.random.set_seed(seed_value)

reset_random_seeds()

# AES S-box and utility functions
AES_Sbox = [
    
]

# Function to compute expected distortion
def compute_expected_distortion(x, s, Vs, model):
    x = tf.cast(x, tf.float32)
    s = tf.cast(s, tf.float32)
    Vs = tf.cast(Vs, tf.float32)
    perturbed_x = x * s + (1 - s) * Vs
    perturbed_x = tf.reshape(perturbed_x, (1, -1, 1))
    x_reshaped = tf.reshape(x, (1, -1, 1))
    original_pred = model.predict(x_reshaped)
    perturbed_pred = model.predict(perturbed_x)
    return np.linalg.norm(original_pred - perturbed_pred)

# Bernoulli sampling and concrete distribution sampling
def concrete_sample(theta, temperature=0.1):
    uniform_noise = tf.random.uniform(theta.shape)
    logistic_noise = tf.math.log(uniform_noise) - tf.math.log(1 - uniform_noise)
    return tf.nn.sigmoid((tf.math.log(theta) - tf.math.log(1 - theta) + logistic_noise) / temperature)

def get_reg(hp):
    if hp["regularization"] == "l1":
        return l1(l1=hp["l1"])
    elif hp["regularization"] == "l2":
        return l2(l2=hp["l2"])
    else:
        return hp["dropout"]

def get_hyperparameters_mlp(regularization=False, max_dense_layers=3):
    if regularization:
        return {
            "batch_size": random.randrange(100, 400, 100),
            "layers": random.randrange(1, max_dense_layers + 1, 1),
            "neurons": random.choice([100, 200, 300, 400]),
            "activation": random.choice(["relu", "selu"]),
            "learning_rate": random.choice([0.0005, 0.0001, 0.00005, 0.00001]),
            "optimizer": random.choice(["Adam", "RMSprop"]),
            "kernel_initializer": random.choice(["random_uniform", "glorot_uniform", "he_uniform"]),
            "regularization": random.choice(["l1", "l2", "dropout"]),
            "l1": random.choice([0.005, 0.001, 0.0005, 0.0001, 0.00005, 0.00001]),
            "l2": random.choice([0.005, 0.001, 0.0005, 0.0001, 0.00005, 0.00001]),
            "dropout": random.choice([0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5])
        }
    else:
        return {
            "batch_size": random.randrange(100, 1100, 100),
            "layers": random.choice([1, 2, 3, 4]),
            "neurons": random.choice([10, 20, 50, 100, 200, 300, 400, 500]),
            "activation": random.choice(["relu", "selu"]),
            "learning_rate": random.choice([0.005, 0.001, 0.0005, 0.0001]),
            "optimizer": random.choice(["Adam", "RMSprop"]),
            "kernel_initializer": random.choice(["random_uniform", "glorot_uniform", "he_uniform"]),
            "regularization": random.choice(["none"])
        }

def get_hyperparameters_cnn(regularization=False):
    hyperparameters = {}
    hyperparameters_mlp = get_hyperparameters_mlp(regularization=regularization, max_dense_layers=3)
    for key, value in hyperparameters_mlp.items():
        hyperparameters[key] = value

    conv_layers = random.choice([1, 2, 3, 4])
    kernels = []
    strides = []
    filters = []
    pooling_types = []
    pooling_sizes = []
    pooling_strides = []
    pooling_type = random.choice(["Average", "Max"])

    for conv_layer in range(1, conv_layers + 1):
        kernel = random.randrange(2, 10, 1)
        kernels.append(kernel)
        strides.append(int(kernel / 2))
        if conv_layer == 1:
            filters.append(random.choice([u for u in range(8, 65, 8)]))
        else:
            filters.append(filters[conv_layer - 2] * 2)
        pool_size = random.choice([2, 3, 4, 5])
        pooling_sizes.append(pool_size)
        pooling_strides.append(pool_size)
        pooling_types.append(pooling_type)

    hyperparameters["conv_layers"] = conv_layers
    hyperparameters["kernels"] = kernels
    hyperparameters["strides"] = strides
    hyperparameters["filters"] = filters
    hyperparameters["pooling_sizes"] = pooling_sizes
    hyperparameters["pooling_strides"] = pooling_strides
    hyperparameters["pooling_types"] = pooling_types

    return hyperparameters

def mlp_random(classes, number_of_samples, regularization=False, hp=None):
    hp = get_hyperparameters_mlp(regularization=regularization) if hp is None else hp
    tf_random_seed = np.random.randint(1048576)
    tf.random.set_seed(tf_random_seed)

    inputs = Input(shape=number_of_samples)
    x = None
    for layer_index in range(hp["layers"]):
        if regularization and hp["regularization"] != "dropout":
            x = Dense(hp["neurons"], activation=hp["activation"], kernel_regularizer=get_reg(hp),
                      kernel_initializer=hp["kernel_initializer"],
                      name='dense_{}'.format(layer_index))(inputs if layer_index == 0 else x)
        else:
            x = Dense(hp["neurons"], activation=hp["activation"], kernel_initializer=hp["kernel_initializer"],
                      name='dense_{}'.format(layer_index))(inputs if layer_index == 0 else x)
        if regularization and hp["regularization"] == "dropout":
            x = Dropout(get_reg(hp))(x)

    outputs = Dense(classes, activation='softmax', name='predictions')(x)
    model = Model(inputs, outputs, name='random_mlp')
    optimizer = get_optimizer(hp["optimizer"], hp["learning_rate"])
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    return model, tf_random_seed, hp

def cnn_random(classes, number_of_samples, regularization=False, hp=None):
    hp = get_hyperparameters_cnn(regularization=regularization) if hp is None else hp
    tf_random_seed = np.random.randint(1048576)
    tf.random.set_seed(tf_random_seed)

    inputs = Input(shape=(number_of_samples, 1))
    x = None
    for layer_index in range(hp["conv_layers"]):
        x = Conv1D(kernel_size=hp["kernels"][layer_index], strides=hp["strides"][layer_index], filters=hp["filters"][layer_index],
                   activation=hp["activation"], padding="same")(inputs if layer_index == 0 else x)
        if hp["pooling_types"][layer_index] == "Average":
            x = AveragePooling1D(pool_size=hp["pooling_sizes"][layer_index], strides=hp["pooling_strides"][layer_index], padding="same")(x)
        else:
            x = MaxPooling1D(pool_size=hp["pooling_sizes"][layer_index], strides=hp["pooling_strides"][layer_index], padding="same")(x)
        x = BatchNormalization()(x)
    x = Flatten()(x)

    for layer_index in range(hp["layers"]):
        if regularization and hp["regularization"] != "dropout":
            x = Dense(hp["neurons"], activation=hp["activation"], kernel_regularizer=get_reg(hp),
                      kernel_initializer=hp["kernel_initializer"], name='dense_{}'.format(layer_index))(x)
        else:
            x = Dense(hp["neurons"], activation=hp["activation"], kernel_initializer=hp["kernel_initializer"],
                      name='dense_{}'.format(layer_index))(x)
        if regularization and hp["regularization"] == "dropout":
            x = Dropout(hp["dropout"])(x)

    outputs = Dense(classes, activation='softmax', name='predictions')(x)
    model = Model(inputs, outputs, name='random_cnn')
    optimizer = get_optimizer(hp["optimizer"], hp["learning_rate"])
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    return model, tf_random_seed, hp

def get_optimizer(optimizer, learning_rate):
    module_name = importlib.import_module("tensorflow.keras.optimizers")
    optimizer_class = getattr(module_name, optimizer)
    return optimizer_class(learning_rate=learning_rate)

# Function for Guessing Entropy (GE) and Correlation Power Analysis (CPA)
def perform_attacks(nb_traces=1000, predictions=None, plt_attack=None, correct_key=None, leakage="HW", dataset=None, nb_attacks=100, shuffle=True):
    all_rk_evol = np.zeros((nb_attacks, nb_traces))
    all_key_log_prob = np.zeros(256)
    for i in tqdm(range(nb_attacks)):
        if shuffle:
            l = list(zip(predictions, plt_attack))
            random.shuffle(l)
            sp, splt = list(zip(*l))
            sp = np.array(sp)
            splt = np.array(splt)
            att_pred = sp[:nb_traces]
            att_plt = splt[:nb_traces]
        else:
            att_pred = predictions[:nb_traces]
            att_plt = plt_attack[:nb_traces]
        rank_evol, key_log_prob = rank_compute(att_pred, att_plt, correct_key, leakage=leakage, dataset=dataset)
        all_rk_evol[i] = rank_evol
        all_key_log_prob += key_log_prob
    return np.mean(all_rk_evol, axis=0), key_log_prob

def rank_compute(prediction, att_plt, correct_key, leakage, dataset):
    hw = [bin(x).count("1") for x in range(256)]
    (nb_traces, nb_hyp) = prediction.shape
    key_log_prob = np.zeros(256)
    prediction = np.log(prediction + 1e-40)
    rank_evol = np.full(nb_traces, 255)
    for i in range(nb_traces):
        for k in range(256):
            att_byte = int(att_plt[i, 0])
            if dataset == "AES_HD_ext":
                if leakage == 'ID':
                    key_log_prob[k] += prediction[i, AES_Sbox_inv[k ^ att_byte] ^ att_byte]
                else:
                    key_log_prob[k] += prediction[i, hw[AES_Sbox_inv[k ^ att_byte] ^ att_byte]]
            elif dataset == "AES_HD_ext_ID":
                if leakage == 'ID':
                    key_log_prob[k] += prediction[i, AES_Sbox_inv[k ^ att_byte]]
                else:
                    key_log_prob[k] += prediction[i, hw[AES_Sbox_inv[k ^ att_byte]]]
            else:
                if leakage == 'ID':
                    key_log_prob[k] += prediction[i, AES_Sbox[k ^ att_byte]]
                else:
                    key_log_prob[k] += prediction[i, hw[AES_Sbox[k ^ att_byte]]]
        rank_evol[i] = rk_key(key_log_prob, correct_key)
    return rank_evol, key_log_prob

def rk_key(rank_array, key):
    key_val = rank_array[key]
    final_rank = np.float32(np.where(np.sort(rank_array)[::-1] == key_val)[0][0])
    if math.isnan(float(final_rank)) or math.isinf(float(final_rank)):
        return np.float32(256)
    else:
        return np.float32(final_rank)

def NTGE_fn(GE):
    NTGE = float('inf')
    for i in range(GE.shape[0] - 1, -1, -1):
        if GE[i] > 0:
            NTGE = i
            break
    return NTGE

def aes_label_cpa(plaintexts, correct_key, leakage):
    num_traces = plaintexts.shape[0]
    labels_for_snr = np.zeros(num_traces)
    for i in range(num_traces):
        if leakage == 'HW':
            labels_for_snr[i] = HW(AES_Sbox[plaintexts[i, 0] ^ correct_key])
        elif leakage == 'ID':
            labels_for_snr[i] = AES_Sbox[plaintexts[i, 0] ^ correct_key]
    return labels_for_snr

def perform_cpa_all_keys(traces, plaintexts, num_keys=256):
    num_traces, num_samples = traces.shape
    correlations = np.zeros((num_keys, num_samples))
    for key_guess in tqdm(range(num_keys)):
        labels_for_cpa = aes_label_cpa(plaintexts, key_guess, leakage)
        for t in range(num_samples):
            correlations[key_guess, t] = abs(np.corrcoef(labels_for_cpa[:num_traces], traces[:, t])[1, 0])
    return correlations

def plot_correlations(correlations, correct_key):
    num_keys, num_samples = correlations.shape
    plt.figure(figsize=(10, 8))
    for key_guess in range(num_keys):
        if key_guess != correct_key:
            plt.plot(correlations[key_guess], color='grey', label='Other Keys' if 'Other Keys' not in plt.gca().get_legend_handles_labels()[1] else "", alpha=0.5, linewidth=1)
    plt.plot(correlations[correct_key], color='blue', label=f'Correct Key: {correct_key:02X}', linewidth=2)
    plt.title('Correlation Power Analysis Across All Key Guesses')
    plt.xlabel('Sample Points')
    plt.ylabel('Absolute Correlation')
    plt.grid(True)
    plt.legend(loc='upper right')
    plt.show()

if __name__ == "__main__":
    # Data loading and preprocessing
    num_traces = 10000
    trace_length = 5000
    leakage = "ID"
    chipwhisper_folder = '/home/localuserplr/Documents/FYP/chipwhisperer/'

    X = np.load(chipwhisper_folder + 'traces.npy')[:num_traces]
    y = np.load(chipwhisper_folder + 'labels.npy')[:num_traces]
    plaintexts = np.load(chipwhisper_folder + 'plain.npy')[:num_traces]
    keys = np.load(chipwhisper_folder + 'key.npy')[:num_traces]

    X = X.reshape((X.shape[0], X.shape[1], 1))

    X_train_val, X_attack, y_train_val, y_attack, plaintexts_train_val, plaintexts_attack = train_test_split(
        X, y, plaintexts, test_size=0.2, random_state=42
    )
    X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.25, random_state=42)

    y_train_categorical = tf.keras.utils.to_categorical(y_train, num_classes=256)
    y_val_categorical = tf.keras.utils.to_categorical(y_val, num_classes=256)

    classes = 256
    number_of_samples = trace_length
    model_type = "cnn"
    regularization = True
    
    # Parameters for perturbation
    k = trace_length
    lamb = 0.1
    num_iterations = 10
    learning_rate = 0.01
    batch_size = 32

    # Initialize theta for Bernoulli distribution
    theta = tf.Variable(np.ones(k) * 0.5, dtype=tf.float32)

    # Optimizer
    optimizer = tf.optimizers.Adam(learning_rate)

    # Initialize model
    model = Sequential([
        Conv1D(32, kernel_size=3, activation='relu', input_shape=(trace_length, 1)),
        Flatten(),
        Dense(256, activation='softmax')
    ])
    model.compile(optimizer=Adam(), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

    # Random data (example)
    x = X_train[:batch_size]  # Example batch
    Vs = np.random.randn(batch_size, k)

    # Optimization loop for feature selection
    for _ in range(num_iterations):
        with tf.GradientTape() as tape:
            s = concrete_sample(theta)
            batch_loss = 0
            for i in range(batch_size):
                # Reshape x[i] and Vs[i] to match the input shape expected by the model
                x_i_reshaped = tf.reshape(x[i], (trace_length, 1))
                Vs_i_reshaped = tf.reshape(Vs[i], (trace_length, 1))
                s_reshaped = tf.reshape(s, (trace_length, 1))
                batch_loss += compute_expected_distortion(x_i_reshaped, s_reshaped, Vs_i_reshaped, model)
            loss = batch_loss / batch_size + lamb * tf.norm(s, ord=1)
        gradients = tape.gradient(loss, [theta])
        optimizer.apply_gradients(zip(gradients, [theta]))

    # Resulting mask
    s = tf.cast(tf.random.uniform(theta.shape) < theta, tf.float32).numpy()

    # Apply the mask to the training data
    X_train_masked = X_train * s[np.newaxis, :, np.newaxis]
    X_val_masked = X_val * s[np.newaxis, :, np.newaxis]

    # Function to create and train models
    def create_and_train_model(x_train, y_train, x_val, y_val, model_type="cnn", regularization=True):
        classes = 256
        number_of_samples = x_train.shape[1]
        if model_type == "mlp":
            hp = get_hyperparameters_mlp(regularization=regularization)
            model, seed, hp = mlp_random(classes, number_of_samples, hp=hp, regularization=regularization)
        else:
            hp = get_hyperparameters_cnn(regularization=regularization)
            model, seed, hp = cnn_random(classes, number_of_samples, hp=hp, regularization=regularization)

        history = model.fit(x_train, y_train, epochs=50, validation_data=(x_val, y_val), batch_size=hp["batch_size"])
        return model, history

    # Function to plot accuracy
    def plot_accuracy(history, title):
        plt.figure(figsize=(10, 6))
        plt.plot(history.history['accuracy'], label='Train Accuracy')
        plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
        plt.title(title)
        plt.xlabel('Epochs')
        plt.ylabel('Accuracy')
        plt.legend()
        plt.grid(True)
        plt.show()

    # Train and evaluate models with and without Bernoulli feature selection
    models = []
    histories_with_bernoulli = []
    histories_without_bernoulli = []

    # With Bernoulli feature selection
    for i in range(5):
        try:
            model, history = create_and_train_model(X_train_masked, y_train_categorical, X_val_masked, y_val_categorical, model_type="cnn", regularization=True)
            models.append(model)
            histories_with_bernoulli.append(history)

            print(f"Model {i+1} summary (with Bernoulli):")
            model.summary()

            predictions = model.predict(X_attack)
            predicted_classes = np.argmax(predictions, axis=1)
            accuracy = np.mean(predicted_classes == y_attack)
            print(f"Test set accuracy for model {i+1} (with Bernoulli): {accuracy}")

            plot_accuracy(history, f'Model {i+1} Accuracy (with Bernoulli)')
        except Exception as e:
            print(f"An error occurred while creating model {i+1} (with Bernoulli): {e}")

    # Without Bernoulli feature selection
    for i in range(5):
        try:
            model, history = create_and_train_model(X_train, y_train_categorical, X_val, y_val_categorical, model_type="cnn", regularization=True)
            models.append(model)
            histories_without_bernoulli.append(history)

            print(f"Model {i+1} summary (without Bernoulli):")
            model.summary()

            predictions = model.predict(X_attack)
            predicted_classes = np.argmax(predictions, axis=1)
            accuracy = np.mean(predicted_classes == y_attack)
            print(f"Test set accuracy for model {i+1} (without Bernoulli): {accuracy}")

            plot_accuracy(history, f'Model {i+1} Accuracy (without Bernoulli)')
        except Exception as e:
            print(f"An error occurred while creating model {i+1} (without Bernoulli): {e}")

    # Compare the average accuracy of models with and without Bernoulli feature selection
    if histories_with_bernoulli:
        avg_train_acc_with_bernoulli = np.mean([history.history['accuracy'][-1] for history in histories_with_bernoulli])
        avg_val_acc_with_bernoulli = np.mean([history.history['val_accuracy'][-1] for history in histories_with_bernoulli])
    else:
        avg_train_acc_with_bernoulli = np.nan
        avg_val_acc_with_bernoulli = np.nan

    if histories_without_bernoulli:
        avg_train_acc_without_bernoulli = np.mean([history.history['accuracy'][-1] for history in histories_without_bernoulli])
        avg_val_acc_without_bernoulli = np.mean([history.history['val_accuracy'][-1] for history in histories_without_bernoulli])
    else:
        avg_train_acc_without_bernoulli = np.nan
        avg_val_acc_without_bernoulli = np.nan

    print(f"Average training accuracy with Bernoulli: {avg_train_acc_with_bernoulli}")
    print(f"Average validation accuracy with Bernoulli: {avg_val_acc_with_bernoulli}")
    print(f"Average training accuracy without Bernoulli: {avg_train_acc_without_bernoulli}")
    print(f"Average validation accuracy without Bernoulli: {avg_val_acc_without_bernoulli}")

    # Plot comparison of average accuracy
    labels = ['Training Accuracy', 'Validation Accuracy']
    with_bernoulli = [avg_train_acc_with_bernoulli, avg_val_acc_with_bernoulli]
    without_bernoulli = [avg_train_acc_without_bernoulli, avg_val_acc_without_bernoulli]

    x = np.arange(len(labels))
    width = 0.35

    fig, ax = plt.subplots(figsize=(10, 6))
    rects1 = ax.bar(x - width/2, with_bernoulli, width, label='With Bernoulli')
    rects2 = ax.bar(x + width/2, without_bernoulli, width, label='Without Bernoulli')

    ax.set_ylabel('Accuracy')
    ax.set_title('Average Accuracy with and without Bernoulli Feature Selection')
    ax.set_xticks(x)
    ax.set_xticklabels(labels)
    ax.legend()

    fig.tight_layout()
    plt.grid(True)
    plt.show()
# Out:
# 2024-08-03 16:24:23.810274: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-08-03 16:24:24.740938: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /home/localuserplr/.local/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Epoch 1/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 7s 97ms/step - accuracy: 0.0040 - loss: 6.2241 - val_accuracy: 0.0060 - val_loss: 6.0491
# Epoch 2/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 10s 92ms/step - accuracy: 0.0050 - loss: 6.0221 - val_accuracy: 0.0055 - val_loss: 5.9534
# Epoch 3/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 6s 95ms/step - accuracy: 0.0076 - loss: 5.9396 - val_accuracy: 0.0030 - val_loss: 5.9124
# Epoch 4/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 10s 99ms/step - accuracy: 0.0052 - loss: 5.9130 - val_accuracy: 0.0055 - val_loss: 5.8917
# Epoch 5/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 10s 90ms/step - accuracy: 0.0050 - loss: 5.8853 - val_accuracy: 0.0055 - val_loss: 5.8706
# Epoch 6/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 6s 92ms/step - accuracy: 0.0068 - loss: 5.8647 - val_accuracy: 0.0055 - val_loss: 5.8526
# Epoch 7/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 5s 90ms/step - accuracy: 0.0077 - loss: 5.8474 - val_accuracy: 0.0055 - val_loss: 5.8356
# Epoch 8/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 10s 91ms/step - accuracy: 0.0067 - loss: 5.8273 - val_accuracy: 0.0040 - val_loss: 5.8208
# Epoch 9/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 10s 91ms/step - accuracy: 0.0040 - loss: 5.8141 - val_accuracy: 0.0015 - val_loss: 5.8110
# Epoch 10/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 6s 92ms/step - accuracy: 0.0064 - loss: 5.7971 - val_accuracy: 0.0055 - val_loss: 5.7945
# Epoch 11/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 5s 91ms/step - accuracy: 0.0075 - loss: 5.7862 - val_accuracy: 0.0030 - val_loss: 5.7865
# Epoch 12/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 6s 92ms/step - accuracy: 0.0052 - loss: 5.7772 - val_accuracy: 0.0035 - val_loss: 5.7748
# Epoch 13/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 10s 93ms/step - accuracy: 0.0053 - loss: 5.7605 - val_accuracy: 0.0055 - val_loss: 5.7601
# Epoch 14/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 6s 92ms/step - accuracy: 0.0072 - loss: 5.7479 - val_accuracy: 0.0055 - val_loss: 5.7496
# Epoch 15/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 6s 91ms/step - accuracy: 0.0071 - loss: 5.7424 - val_accuracy: 0.0055 - val_loss: 5.7402
# Epoch 16/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 6s 92ms/step - accuracy: 0.0074 - loss: 5.7326 - val_accuracy: 0.0055 - val_loss: 5.7313
# Epoch 17/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 6s 93ms/step - accuracy: 0.0074 - loss: 5.7230 - val_accuracy: 0.0055 - val_loss: 5.7239
# Epoch 18/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 10s 93ms/step - accuracy: 0.0050 - loss: 5.7120 - val_accuracy: 0.0035 - val_loss: 5.7162
# Epoch 19/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 6s 92ms/step - accuracy: 0.0053 - loss: 5.7029 - val_accuracy: 0.0055 - val_loss: 5.7097
# Epoch 20/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 10s 92ms/step - accuracy: 0.0074 - loss: 5.6934 - val_accuracy: 0.0055 - val_loss: 5.7053
# Epoch 21/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 6s 94ms/step - accuracy: 0.0074 - loss: 5.6876 - val_accuracy: 0.0055 - val_loss: 5.7063
# Epoch 22/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 6s 92ms/step - accuracy: 0.0074 - loss: 5.6816 - val_accuracy: 0.0055 - val_loss: 5.7029
# Epoch 23/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 6s 92ms/step - accuracy: 0.0074 - loss: 5.6757 - val_accuracy: 0.0055 - val_loss: 5.7024
# Epoch 24/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 10s 90ms/step - accuracy: 0.0074 - loss: 5.6688 - val_accuracy: 0.0055 - val_loss: 5.6980
# Epoch 25/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 6s 93ms/step - accuracy: 0.0074 - loss: 5.6628 - val_accuracy: 0.0055 - val_loss: 5.6933
# Epoch 26/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 5s 91ms/step - accuracy: 0.0074 - loss: 5.6573 - val_accuracy: 0.0055 - val_loss: 5.6890
# Epoch 27/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 5s 91ms/step - accuracy: 0.0074 - loss: 5.6524 - val_accuracy: 0.0055 - val_loss: 5.6847
# Epoch 28/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 6s 93ms/step - accuracy: 0.0074 - loss: 5.6480 - val_accuracy: 0.0055 - val_loss: 5.6809
# Epoch 29/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 10s 91ms/step - accuracy: 0.0074 - loss: 5.6437 - val_accuracy: 0.0055 - val_loss: 5.6771
# Epoch 30/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 6s 92ms/step - accuracy: 0.0074 - loss: 5.6397 - val_accuracy: 0.0055 - val_loss: 5.6732
# Epoch 31/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 6s 95ms/step - accuracy: 0.0074 - loss: 5.6378 - val_accuracy: 0.0055 - val_loss: 5.6692
# Epoch 32/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 6s 93ms/step - accuracy: 0.0074 - loss: 5.6331 - val_accuracy: 0.0055 - val_loss: 5.6673
# Epoch 33/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 6s 95ms/step - accuracy: 0.0074 - loss: 5.6295 - val_accuracy: 0.0055 - val_loss: 5.6645
# Epoch 34/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 6s 94ms/step - accuracy: 0.0074 - loss: 5.6266 - val_accuracy: 0.0055 - val_loss: 5.6622
# Epoch 35/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 6s 94ms/step - accuracy: 0.0074 - loss: 5.6239 - val_accuracy: 0.0055 - val_loss: 5.6594
# Epoch 36/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 6s 95ms/step - accuracy: 0.0074 - loss: 5.6209 - val_accuracy: 0.0055 - val_loss: 5.6583
# Epoch 37/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 10s 96ms/step - accuracy: 0.0074 - loss: 5.6218 - val_accuracy: 0.0055 - val_loss: 5.6546
# Epoch 38/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 6s 96ms/step - accuracy: 0.0074 - loss: 5.6162 - val_accuracy: 0.0055 - val_loss: 5.6519
# Epoch 39/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 10s 96ms/step - accuracy: 0.0082 - loss: 5.6146 - val_accuracy: 0.0055 - val_loss: 5.6509
# Epoch 40/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 6s 96ms/step - accuracy: 0.0074 - loss: 5.6120 - val_accuracy: 0.0055 - val_loss: 5.6489
# Epoch 41/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 10s 93ms/step - accuracy: 0.0074 - loss: 5.6099 - val_accuracy: 0.0055 - val_loss: 5.6467
# Epoch 42/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 6s 94ms/step - accuracy: 0.0074 - loss: 5.6077 - val_accuracy: 0.0055 - val_loss: 5.6448
# Epoch 43/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 6s 96ms/step - accuracy: 0.0074 - loss: 5.6059 - val_accuracy: 0.0055 - val_loss: 5.6432
# Epoch 44/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 6s 95ms/step - accuracy: 0.0074 - loss: 5.6041 - val_accuracy: 0.0055 - val_loss: 5.6414
# Epoch 45/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 10s 95ms/step - accuracy: 0.0074 - loss: 5.6026 - val_accuracy: 0.0055 - val_loss: 5.6399
# Epoch 46/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 6s 95ms/step - accuracy: 0.0074 - loss: 5.6010 - val_accuracy: 0.0055 - val_loss: 5.6383
# Epoch 47/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 6s 94ms/step - accuracy: 0.0074 - loss: 5.5993 - val_accuracy: 0.0055 - val_loss: 5.6369
# Epoch 48/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 6s 95ms/step - accuracy: 0.0074 - loss: 5.5983 - val_accuracy: 0.0055 - val_loss: 5.6355
# Epoch 49/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 6s 92ms/step - accuracy: 0.0074 - loss: 5.5976 - val_accuracy: 0.0055 - val_loss: 5.6345
# Epoch 50/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 5s 91ms/step - accuracy: 0.0074 - loss: 5.5959 - val_accuracy: 0.0055 - val_loss: 5.6332
# Model 1 summary (with Bernoulli):
# Model: "random_cnn"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 5000, 1)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 5000, 8)        │            24 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 2500, 8)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 2500, 8)        │            32 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 20000)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_0 (Dense)                 │ (None, 300)            │     6,000,300 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 300)            │        90,300 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 300)            │        90,300 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ predictions (Dense)             │ (None, 256)            │        77,056 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 18,774,006 (71.62 MB)
#  Trainable params: 6,257,996 (23.87 MB)
#  Non-trainable params: 16 (64.00 B)
#  Optimizer params: 12,515,994 (47.74 MB)
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step
# Test set accuracy for model 1 (with Bernoulli): 0.002
# Epoch 1/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 17s 807ms/step - accuracy: 0.0028 - loss: 8.6974 - val_accuracy: 0.0035 - val_loss: 6.7633
# Epoch 2/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 16s 809ms/step - accuracy: 0.0020 - loss: 7.2796 - val_accuracy: 0.0035 - val_loss: 6.7841
# Epoch 3/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 788ms/step - accuracy: 0.0021 - loss: 6.9685 - val_accuracy: 0.0055 - val_loss: 6.8151
# Epoch 4/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 16s 800ms/step - accuracy: 0.0031 - loss: 6.8499 - val_accuracy: 0.0060 - val_loss: 6.8556
# Epoch 5/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 16s 803ms/step - accuracy: 0.0031 - loss: 6.8011 - val_accuracy: 0.0060 - val_loss: 6.9051
# Epoch 6/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 16s 810ms/step - accuracy: 0.0024 - loss: 6.7786 - val_accuracy: 0.0060 - val_loss: 6.9629
# Epoch 7/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 16s 804ms/step - accuracy: 0.0031 - loss: 6.7656 - val_accuracy: 0.0060 - val_loss: 7.0290
# Epoch 8/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 16s 803ms/step - accuracy: 0.0043 - loss: 6.7594 - val_accuracy: 0.0060 - val_loss: 7.1014
# Epoch 9/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 789ms/step - accuracy: 0.0050 - loss: 6.7533 - val_accuracy: 0.0060 - val_loss: 7.1812
# Epoch 10/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 18s 880ms/step - accuracy: 0.0052 - loss: 6.7489 - val_accuracy: 0.0060 - val_loss: 7.2676
# Epoch 11/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 17s 875ms/step - accuracy: 0.0053 - loss: 6.7448 - val_accuracy: 0.0060 - val_loss: 7.3618
# Epoch 12/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 16s 808ms/step - accuracy: 0.0059 - loss: 6.7417 - val_accuracy: 0.0060 - val_loss: 7.4630
# Epoch 13/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 795ms/step - accuracy: 0.0060 - loss: 6.7389 - val_accuracy: 0.0060 - val_loss: 7.5716
# Epoch 14/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 16s 827ms/step - accuracy: 0.0058 - loss: 6.7366 - val_accuracy: 0.0060 - val_loss: 7.6906
# Epoch 15/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 808ms/step - accuracy: 0.0064 - loss: 6.7335 - val_accuracy: 0.0060 - val_loss: 7.8222
# Epoch 16/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 17s 828ms/step - accuracy: 0.0062 - loss: 6.7322 - val_accuracy: 0.0060 - val_loss: 7.9596
# Epoch 17/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 16s 820ms/step - accuracy: 0.0074 - loss: 6.7296 - val_accuracy: 0.0060 - val_loss: 8.1102
# Epoch 18/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 812ms/step - accuracy: 0.0060 - loss: 6.7277 - val_accuracy: 0.0060 - val_loss: 8.2764
# Epoch 19/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 813ms/step - accuracy: 0.0073 - loss: 6.7254 - val_accuracy: 0.0060 - val_loss: 8.4525
# Epoch 20/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 21s 821ms/step - accuracy: 0.0074 - loss: 6.7237 - val_accuracy: 0.0060 - val_loss: 8.6114
# Epoch 21/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 811ms/step - accuracy: 0.0081 - loss: 6.7217 - val_accuracy: 0.0060 - val_loss: 8.7459
# Epoch 22/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 809ms/step - accuracy: 0.0075 - loss: 6.7200 - val_accuracy: 0.0060 - val_loss: 8.8678
# Epoch 23/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 21s 812ms/step - accuracy: 0.0077 - loss: 6.7170 - val_accuracy: 0.0060 - val_loss: 8.9672
# Epoch 24/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 16s 819ms/step - accuracy: 0.0083 - loss: 6.7153 - val_accuracy: 0.0060 - val_loss: 9.0266
# Epoch 25/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 17s 828ms/step - accuracy: 0.0092 - loss: 6.7135 - val_accuracy: 0.0060 - val_loss: 9.0457
# Epoch 26/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 17s 826ms/step - accuracy: 0.0080 - loss: 6.7111 - val_accuracy: 0.0060 - val_loss: 9.0156
# Epoch 27/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 815ms/step - accuracy: 0.0091 - loss: 6.7091 - val_accuracy: 0.0060 - val_loss: 8.9427
# Epoch 28/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 809ms/step - accuracy: 0.0088 - loss: 6.7070 - val_accuracy: 0.0060 - val_loss: 8.8228
# Epoch 29/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 17s 827ms/step - accuracy: 0.0083 - loss: 6.7046 - val_accuracy: 0.0060 - val_loss: 8.6600
# Epoch 30/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 16s 823ms/step - accuracy: 0.0084 - loss: 6.7022 - val_accuracy: 0.0060 - val_loss: 8.4630
# Epoch 31/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 815ms/step - accuracy: 0.0087 - loss: 6.7000 - val_accuracy: 0.0060 - val_loss: 8.2453
# Epoch 32/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 17s 843ms/step - accuracy: 0.0085 - loss: 6.6985 - val_accuracy: 0.0060 - val_loss: 8.0119
# Epoch 33/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 17s 864ms/step - accuracy: 0.0097 - loss: 6.6963 - val_accuracy: 0.0060 - val_loss: 7.7758
# Epoch 34/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 17s 850ms/step - accuracy: 0.0096 - loss: 6.6941 - val_accuracy: 0.0060 - val_loss: 7.5483
# Epoch 35/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 829ms/step - accuracy: 0.0089 - loss: 6.6914 - val_accuracy: 0.0060 - val_loss: 7.3424
# Epoch 36/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 17s 832ms/step - accuracy: 0.0094 - loss: 6.6898 - val_accuracy: 0.0060 - val_loss: 7.1860
# Epoch 37/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 824ms/step - accuracy: 0.0102 - loss: 6.6874 - val_accuracy: 0.0060 - val_loss: 7.0682
# Epoch 38/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 818ms/step - accuracy: 0.0109 - loss: 6.6852 - val_accuracy: 0.0060 - val_loss: 6.9786
# Epoch 39/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 17s 830ms/step - accuracy: 0.0101 - loss: 6.6828 - val_accuracy: 0.0060 - val_loss: 6.9121
# Epoch 40/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 17s 830ms/step - accuracy: 0.0109 - loss: 6.6808 - val_accuracy: 0.0060 - val_loss: 6.8607
# Epoch 41/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 817ms/step - accuracy: 0.0121 - loss: 6.6787 - val_accuracy: 0.0070 - val_loss: 6.8256
# Epoch 42/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 17s 827ms/step - accuracy: 0.0122 - loss: 6.6760 - val_accuracy: 0.0080 - val_loss: 6.7994
# Epoch 43/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 17s 827ms/step - accuracy: 0.0119 - loss: 6.6739 - val_accuracy: 0.0070 - val_loss: 6.7800
# Epoch 44/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 17s 830ms/step - accuracy: 0.0114 - loss: 6.6716 - val_accuracy: 0.0055 - val_loss: 6.7686
# Epoch 45/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 818ms/step - accuracy: 0.0111 - loss: 6.6692 - val_accuracy: 0.0050 - val_loss: 6.7587
# Epoch 46/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 17s 833ms/step - accuracy: 0.0113 - loss: 6.6670 - val_accuracy: 0.0065 - val_loss: 6.7533
# Epoch 47/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 17s 851ms/step - accuracy: 0.0121 - loss: 6.6644 - val_accuracy: 0.0060 - val_loss: 6.7489
# Epoch 48/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 17s 832ms/step - accuracy: 0.0125 - loss: 6.6620 - val_accuracy: 0.0050 - val_loss: 6.7451
# Epoch 49/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 818ms/step - accuracy: 0.0124 - loss: 6.6599 - val_accuracy: 0.0070 - val_loss: 6.7421
# Epoch 50/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 811ms/step - accuracy: 0.0133 - loss: 6.6571 - val_accuracy: 0.0075 - val_loss: 6.7401
# Model 2 summary (with Bernoulli):
# Model: "random_cnn"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 5000, 1)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_2 (Conv1D)               │ (None, 2500, 48)       │           288 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling1d               │ (None, 1250, 48)       │             0 │
# │ (AveragePooling1D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 1250, 48)       │           192 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_3 (Conv1D)               │ (None, 1250, 96)       │        13,920 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling1d_1             │ (None, 250, 96)        │             0 │
# │ (AveragePooling1D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 250, 96)        │           384 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_4 (Conv1D)               │ (None, 250, 192)       │        55,488 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling1d_2             │ (None, 63, 192)        │             0 │
# │ (AveragePooling1D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 63, 192)        │           768 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 12096)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_0 (Dense)                 │ (None, 400)            │     4,838,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ predictions (Dense)             │ (None, 256)            │       102,656 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10,024,322 (38.24 MB)
#  Trainable params: 5,011,824 (19.12 MB)
#  Non-trainable params: 672 (2.62 KB)
#  Optimizer params: 5,011,826 (19.12 MB)
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step
# Test set accuracy for model 2 (with Bernoulli): 0.004
# Epoch 1/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 18s 271ms/step - accuracy: 0.0031 - loss: 5.7738 - val_accuracy: 0.0070 - val_loss: 5.6629
# Epoch 2/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 17s 282ms/step - accuracy: 0.0038 - loss: 5.6854 - val_accuracy: 0.0070 - val_loss: 5.6618
# Epoch 3/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 19s 251ms/step - accuracy: 0.0041 - loss: 5.6753 - val_accuracy: 0.0070 - val_loss: 5.6615
# Epoch 4/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 15s 254ms/step - accuracy: 0.0060 - loss: 5.6680 - val_accuracy: 0.0070 - val_loss: 5.6628
# Epoch 5/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 16s 259ms/step - accuracy: 0.0039 - loss: 5.6625 - val_accuracy: 0.0070 - val_loss: 5.6648
# Epoch 6/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 15s 252ms/step - accuracy: 0.0042 - loss: 5.6595 - val_accuracy: 0.0070 - val_loss: 5.6678
# Epoch 7/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 16s 265ms/step - accuracy: 0.0049 - loss: 5.6546 - val_accuracy: 0.0070 - val_loss: 5.6700
# Epoch 8/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 21s 267ms/step - accuracy: 0.0031 - loss: 5.6541 - val_accuracy: 0.0060 - val_loss: 5.6698
# Epoch 9/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 16s 273ms/step - accuracy: 0.0031 - loss: 5.6519 - val_accuracy: 0.0055 - val_loss: 5.6655
# Epoch 10/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 16s 274ms/step - accuracy: 0.0055 - loss: 5.6484 - val_accuracy: 0.0045 - val_loss: 5.6597
# Epoch 11/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 16s 259ms/step - accuracy: 0.0041 - loss: 5.6482 - val_accuracy: 0.0035 - val_loss: 5.6554
# Epoch 12/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 16s 266ms/step - accuracy: 0.0050 - loss: 5.6457 - val_accuracy: 0.0020 - val_loss: 5.6534
# Epoch 13/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 16s 263ms/step - accuracy: 0.0046 - loss: 5.6441 - val_accuracy: 0.0040 - val_loss: 5.6545
# Epoch 14/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 17s 277ms/step - accuracy: 0.0058 - loss: 5.6431 - val_accuracy: 0.0040 - val_loss: 5.6530
# Epoch 15/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 18s 293ms/step - accuracy: 0.0055 - loss: 5.6419 - val_accuracy: 0.0035 - val_loss: 5.6543
# Epoch 16/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 17s 290ms/step - accuracy: 0.0052 - loss: 5.6397 - val_accuracy: 0.0045 - val_loss: 5.6524
# Epoch 17/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 18s 293ms/step - accuracy: 0.0059 - loss: 5.6382 - val_accuracy: 0.0030 - val_loss: 5.6497
# Epoch 18/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 17s 287ms/step - accuracy: 0.0039 - loss: 5.6368 - val_accuracy: 0.0020 - val_loss: 5.6507
# Epoch 19/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 20s 287ms/step - accuracy: 0.0046 - loss: 5.6347 - val_accuracy: 0.0035 - val_loss: 5.6501
# Epoch 20/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 20s 287ms/step - accuracy: 0.0044 - loss: 5.6336 - val_accuracy: 0.0020 - val_loss: 5.6498
# Epoch 21/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 17s 287ms/step - accuracy: 0.0056 - loss: 5.6318 - val_accuracy: 0.0040 - val_loss: 5.6498
# Epoch 22/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 16s 272ms/step - accuracy: 0.0052 - loss: 5.6305 - val_accuracy: 0.0045 - val_loss: 5.6485
# Epoch 23/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 21s 281ms/step - accuracy: 0.0058 - loss: 5.6295 - val_accuracy: 0.0055 - val_loss: 5.6477
# Epoch 24/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 16s 259ms/step - accuracy: 0.0046 - loss: 5.6278 - val_accuracy: 0.0030 - val_loss: 5.6477
# Epoch 25/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 17s 279ms/step - accuracy: 0.0082 - loss: 5.6269 - val_accuracy: 0.0055 - val_loss: 5.6442
# Epoch 26/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 16s 267ms/step - accuracy: 0.0074 - loss: 5.6239 - val_accuracy: 0.0055 - val_loss: 5.6447
# Epoch 27/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 18s 300ms/step - accuracy: 0.0077 - loss: 5.6231 - val_accuracy: 0.0055 - val_loss: 5.6440
# Epoch 28/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 16s 274ms/step - accuracy: 0.0065 - loss: 5.6215 - val_accuracy: 0.0055 - val_loss: 5.6438
# Epoch 29/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 16s 270ms/step - accuracy: 0.0077 - loss: 5.6194 - val_accuracy: 0.0055 - val_loss: 5.6427
# Epoch 30/50
# 54/60 ━━━━━━━━━━━━━━━━━━━━ 1s 233ms/step - accuracy: 0.0077 - loss: 5.6178
